# %%
import pandas as pd

# %%
df = pd.read_csv('D:\data science trainning\pandas\survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# to look for number of row and col we use shape 
df.shape
# Out:
# (88883, 85)

# %%
# because info is method we put parathensis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
df_schema = pd.read_csv("D:\data science trainning\pandas\survey_results_schema.csv")

# %%
df_schema
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
#show the first ten columns 
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
#show the last ten values 
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
#if we want to slicing the row like a list
df.loc[0:3,'Hobbyist':'Extraversion']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# ...

# %%
df.iloc[[1,2,3,4],5]
# Out:
# 1    Not employed, but looking for work
# 2                    Employed full-time
# 3                    Employed full-time
# 4                    Employed full-time
# Name: Employment, dtype: object

# %%
#to set an index 
df.set_index('Country',inplace =True)
# now country become an index to a dataframe

# %%
#to select the first row 
df.index
# Out:
# Index([        'United Kingdom', 'Bosnia and Herzegovina',
#                      'Thailand',          'United States',
#                       'Ukraine',                 'Canada',
#                       'Ukraine',                  'India',
#                   'New Zealand',                  'India',
#        ...
#                             nan,                      nan,
#                      'Pakistan',                  'Spain',
#                 'United States',                 'Canada',
#                             nan,                      nan,
#                             nan,                  'Spain'],
#       dtype='object', name='Country', length=88883)

# %%
# to select row  called Thailand
df.loc['Thailand']
# Out:
#           Respondent                                         MainBranch  \
# Country
# Thailand           3  I am not primarily a developer, but I write co...
# Thailand         255             I am a student who is learning to code
# Thailand         736                     I am a developer by profession
# Thailand        1602                     I am a developer by profession
# Thailand        1660             I am a student who is learning to code
# ...              ...                                                ...
# Thailand       53984                                                NaN
# Thailand       68027                                                NaN
# Thailand       68401                                                NaN
# Thailand       75530                                                NaN
# Thailand       83612                                                NaN
#
#          Hobbyist                                        OpenSourcer  \
# Country
# ...

# %%
# to select the index as before we use 
# we use inplace = true to modify the data frame 
df.reset_index(inplace= True)

# %%
df
# Out:
#                       Country  Respondent  \
# 0              United Kingdom           1
# 1      Bosnia and Herzegovina           2
# 2                    Thailand           3
# 3               United States           4
# 4                     Ukraine           5
# ...                       ...         ...
# 88878                  Canada       88377
# 88879                     NaN       88601
# 88880                     NaN       88802
# 88881                     NaN       88816
# 88882                   Spain       88863
#
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...

# %%
df.sort_index(ascending = False)
# Out:
#                       Country  Respondent  \
# 88882                   Spain       88863
# 88881                     NaN       88816
# 88880                     NaN       88802
# 88879                     NaN       88601
# 88878                  Canada       88377
# ...                       ...         ...
# 4                     Ukraine           5
# 3               United States           4
# 2                    Thailand           3
# 1      Bosnia and Herzegovina           2
# 0              United Kingdom           1
#
#                                               MainBranch Hobbyist  \
# 88882                                                NaN      Yes
# 88881                                                NaN       No
# 88880                                                NaN       No
# 88879                                                NaN       No
# 88878                                                NaN      Yes
# ...

# %%
high_salary =(df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary]
# Out:
#               Country  Respondent  \
# 5              Canada           6
# 8         New Zealand           9
# 12      United States          13
# 15     United Kingdom          16
# 21      United States          22
# ...               ...         ...
# 88323   United States       88876
# 88324   United States       88877
# 88325   United States       88878
# 88326         Finland       88879
# 88329     Netherlands       88882
#
#                                               MainBranch Hobbyist  \
# 5      I am not primarily a developer, but I write co...      Yes
# 8                         I am a developer by profession      Yes
# 12                        I am a developer by profession      Yes
# 15                        I am a developer by profession      Yes
# 21                        I am a developer by profession      Yes
# ...                                                  ...      ...
# 88323                     I am a developer by profession      Yes
# ...

# %%
# that show the country that have convertedcomp more than 7000 
df.loc[high_salary,'Country']
# Out:
# 5                Canada
# 8           New Zealand
# 12        United States
# 15       United Kingdom
# 21        United States
#               ...
# 88323     United States
# 88324     United States
# 88325     United States
# 88326           Finland
# 88329       Netherlands
# Name: Country, Length: 22289, dtype: object

# %%
countries = ['Canada','New Zealand','Finland']
# check if the country is one of the three country if it is return true 
filt = df['Country'].isin(countries)

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
# the first parameter to select the row according to the condition
# second parameter to select the coloumn to show you the country that selected
df.loc[filt,'Country']
# Out:
# 5             Canada
# 8        New Zealand
# 11            Canada
# 20            Canada
# 30            Canada
#             ...
# 88771         Canada
# 88801         Canada
# 88838         Canada
# 88855         Canada
# 88878         Canada
# Name: Country, Length: 4465, dtype: object

# %%
for x in df.columns:
    print(x.upper())
# Out:
# COUNTRY
# RESPONDENT
# MAINBRANCH
# HOBBYIST
# OPENSOURCER
# OPENSOURCE
# EMPLOYMENT
# STUDENT
# EDLEVEL
# UNDERGRADMAJOR
# EDUOTHER
# ORGSIZE
# DEVTYPE
# YEARSCODE
# AGE1STCODE
# YEARSCODEPRO
# CAREERSAT
# JOBSAT
# MGRIDIOT
# MGRMONEY
# MGRWANT
# JOBSEEK
# LASTHIREDATE
# LASTINT
# FIZZBUZZ
# JOBFACTORS
# RESUMEUPDATE
# CURRENCYSYMBOL
# CURRENCYDESC
# COMPTOTAL
# COMPFREQ
# CONVERTEDCOMP
# WORKWEEKHRS
# WORKPLAN
# WORKCHALLENGE
# WORKREMOTE
# WORKLOC
# IMPSYN
# CODEREV
# CODEREVHRS
# UNITTESTS
# PURCHASEHOW
# PURCHASEWHAT
# LANGUAGEWORKEDWITH
# LANGUAGEDESIRENEXTYEAR
# DATABASEWORKEDWITH
# DATABASEDESIRENEXTYEAR
# PLATFORMWORKEDWITH
# PLATFORMDESIRENEXTYEAR
# WEBFRAMEWORKEDWITH
# WEBFRAMEDESIRENEXTYEAR
# MISCTECHWORKEDWITH
# MISCTECHDESIRENEXTYEAR
# DEVENVIRON
# OPSYS
# CONTAINERS
# BLOCKCHAINORG
# BLOCKCHAINIS
# BETTERLIFE
# ITPERSON
# OFFON
# SOCIALMEDIA
# EXTRAVERSION
# SCREENNAME
# SOVISIT1ST
# SOVISITFREQ
# SOVISITTO
# SOFINDANSWER
# SOTIMESAVED
# SOHOWMUCHTIME
# SOACCOUNT
# ...

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns = [x.lower() for x in df.columns]

# %%
len(df['country'])
# Out:
# 88883

# %%
df.head()
# Out:
#                   country  respondent  \
# 0          United Kingdom           1
# 1  Bosnia and Herzegovina           2
# 2                Thailand           3
# 3           United States           4
# 4                 Ukraine           5
#
#                                           mainbranch hobbyist  \
# 0             I am a student who is learning to code      Yes
# 1             I am a student who is learning to code       No
# 2  I am not primarily a developer, but I write co...      Yes
# 3                     I am a developer by profession       No
# 4                     I am a developer by profession      Yes
#
#                   opensourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           opensource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# ...

# %%
# replace function take at least two argument
df['country'].replace({'United Kingdom':'Egypt','Bosnia and Herzegovina':'cc'})
# Out:
# 0                Egypt
# 1                   cc
# 2             Thailand
# 3        United States
# 4              Ukraine
#              ...
# 88878           Canada
# 88879              NaN
# 88880              NaN
# 88881              NaN
# 88882            Spain
# Name: country, Length: 88883, dtype: object

# %%
df.rename(columns={'convertedcomp':'SalaryUSD'},inplace =True)

# %%
df['hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: hobbyist, Length: 88883, dtype: object

# %%
df['hobbyist'].map({'Yes':True,'No':False})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: hobbyist, Length: 88883, dtype: bool

# %%
# we can can drop column use drop function 
df.drop(index = df[df['country'] == 'United Kingdom'].index)
# Out:
#                       country  respondent  \
# 1      Bosnia and Herzegovina           2
# 2                    Thailand           3
# 3               United States           4
# 4                     Ukraine           5
# 5                      Canada           6
# ...                       ...         ...
# 88878                  Canada       88377
# 88879                     NaN       88601
# 88880                     NaN       88802
# 88881                     NaN       88816
# 88882                   Spain       88863
#
#                                               mainbranch hobbyist  \
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# 5      I am not primarily a developer, but I write co...      Yes
# ...

# %%
df.sort_values(by = 'country',ascending=False)
# Out:
#         country  respondent  \
# 69054  Zimbabwe       69495
# 51025  Zimbabwe       51356
# 6460   Zimbabwe        6486
# 1878   Zimbabwe        1886
# 55057  Zimbabwe       55405
# ...         ...         ...
# 88873       NaN       88062
# 88874       NaN       88076
# 88879       NaN       88601
# 88880       NaN       88802
# 88881       NaN       88816
#
#                                               mainbranch hobbyist  \
# 69054  I used to be a developer by profession, but no...       No
# 51025             I am a student who is learning to code       No
# 6460              I am a student who is learning to code      Yes
# 1878                      I am a developer by profession      Yes
# 55057                     I am a developer by profession      Yes
# ...                                                  ...      ...
# 88873                                                NaN       No
# 88874                                                NaN       No
# ...

# %%
df.sort_values(by = ['country' , 'yearscode'],ascending=[False,True])
# Out:
#         country  respondent                              mainbranch hobbyist  \
# 21851  Zimbabwe       21968  I am a student who is learning to code      Yes
# 23033  Zimbabwe       23162             I code primarily as a hobby      Yes
# 55057  Zimbabwe       55405          I am a developer by profession      Yes
# 1878   Zimbabwe        1886          I am a developer by profession      Yes
# 76118  Zimbabwe       76594          I am a developer by profession       No
# ...         ...         ...                                     ...      ...
# 88873       NaN       88062                                     NaN       No
# 88874       NaN       88076                                     NaN       No
# 88879       NaN       88601                                     NaN       No
# 88880       NaN       88802                                     NaN       No
# 88881       NaN       88816                                     NaN       No
#
# ...

# %%
# function count the non missing row 
df['SalaryUSD'].count()
# Out:
# 55823

# %%
country_grp = df.groupby(['country'])

# %%
country_grp.get_group('Zimbabwe')
# Out:
#         country  respondent  \
# 249    Zimbabwe         251
# 1878   Zimbabwe        1886
# 2521   Zimbabwe        2530
# 3829   Zimbabwe        3845
# 3975   Zimbabwe        3991
# 5087   Zimbabwe        5110
# 6460   Zimbabwe        6486
# 6466   Zimbabwe        6492
# 11007  Zimbabwe       11057
# 13329  Zimbabwe       13392
# 15220  Zimbabwe       15299
# 15847  Zimbabwe       15930
# 18604  Zimbabwe       18707
# 21851  Zimbabwe       21968
# 22241  Zimbabwe       22363
# 22848  Zimbabwe       22975
# 23033  Zimbabwe       23162
# 26077  Zimbabwe       26228
# 30560  Zimbabwe       30743
# 32759  Zimbabwe       32960
# 34874  Zimbabwe       35092
# 46943  Zimbabwe       47247
# 47789  Zimbabwe       48100
# 51025  Zimbabwe       51356
# 51133  Zimbabwe       51464
# 52708  Zimbabwe       53047
# 54080  Zimbabwe       54422
# 54376  Zimbabwe       54719
# 55057  Zimbabwe       55405
# 57527  Zimbabwe       57894
# 60693  Zimbabwe       61083
# 64307  Zimbabwe       64719
# ...

# %%
df.loc[df['country'] == 'Zimbabwe']
# Out:
#         country  respondent  \
# 249    Zimbabwe         251
# 1878   Zimbabwe        1886
# 2521   Zimbabwe        2530
# 3829   Zimbabwe        3845
# 3975   Zimbabwe        3991
# 5087   Zimbabwe        5110
# 6460   Zimbabwe        6486
# 6466   Zimbabwe        6492
# 11007  Zimbabwe       11057
# 13329  Zimbabwe       13392
# 15220  Zimbabwe       15299
# 15847  Zimbabwe       15930
# 18604  Zimbabwe       18707
# 21851  Zimbabwe       21968
# 22241  Zimbabwe       22363
# 22848  Zimbabwe       22975
# 23033  Zimbabwe       23162
# 26077  Zimbabwe       26228
# 30560  Zimbabwe       30743
# 32759  Zimbabwe       32960
# 34874  Zimbabwe       35092
# 46943  Zimbabwe       47247
# 47789  Zimbabwe       48100
# 51025  Zimbabwe       51356
# 51133  Zimbabwe       51464
# 52708  Zimbabwe       53047
# 54080  Zimbabwe       54422
# 54376  Zimbabwe       54719
# 55057  Zimbabwe       55405
# 57527  Zimbabwe       57894
# 60693  Zimbabwe       61083
# 64307  Zimbabwe       64719
# ...

# %%
country_grp['platformworkedwith'].value_counts()
# Out:
# country      platformworkedwith
# Afghanistan  Android;Linux;Windows                                      5
#              Windows                                                    5
#              Linux                                                      2
#              WordPress                                                  2
#              Android;AWS;Linux;Windows;WordPress                        1
#                                                                        ..
# Zimbabwe     Docker;Linux;Windows                                       1
#              Google Cloud Platform;IBM Cloud or Watson;Slack;Windows    1
#              Heroku;Linux;Microsoft Azure;Slack;Windows                 1
#              MacOS;Slack                                                1
#              Windows;WordPress                                          1
# Name: platformworkedwith, Length: 30673, dtype: int64

# %%
country_grp['platformworkedwith'].value_counts().loc['Afghanistan']
# Out:
# platformworkedwith
# Android;Linux;Windows                                                                                                 5
# Windows                                                                                                               5
# Linux                                                                                                                 2
# WordPress                                                                                                             2
# Android;AWS;Linux;Windows;WordPress                                                                                   1
# Android;Arduino;AWS;Docker;Google Cloud Platform;Heroku;IBM Cloud or Watson;Kubernetes;Linux;MacOS;Microsoft Azure    1
# Android;Arduino;Docker;Google Cloud Platform;iOS;Kubernetes;Linux;Slack;Windows                                       1
# Android;Docker;Heroku                                                                                                 1
# ...

# %%
country_grp['SalaryUSD'].agg(['mean','median'])
# Out:
#                                                mean    median
# country
# Afghanistan                           101953.333333    6222.0
# Albania                                21833.700000   10818.0
# Algeria                                34924.047619    7878.0
# Andorra                               160931.000000  160931.0
# Angola                                  7764.000000    7764.0
# ...                                             ...       ...
# Venezuela, Bolivarian Republic of...   14581.627907    6384.0
# Viet Nam                               17233.436782   11892.0
# Yemen                                  16909.166667   11940.0
# Zambia                                 10075.375000    5040.0
# Zimbabwe                               34046.666667   19200.0
#
# [179 rows x 2 columns]

# %%
filt = df['country'] == 'Zimbabwe'
df.loc[filt]
df.loc[filt]['languageworkedwith'].str.contains('JavaScript')
# Out:
# 249       True
# 1878      True
# 2521      True
# 3829      True
# 3975     False
# 5087     False
# 6460     False
# 6466      True
# 11007     True
# 13329    False
# 15220     True
# 15847     True
# 18604     True
# 21851    False
# 22241     True
# 22848     True
# 23033     True
# 26077    False
# 30560     True
# 32759     True
# 34874     True
# 46943     True
# 47789    False
# 51025    False
# 51133    False
# 52708    False
# 54080     True
# 54376     True
# 55057    False
# 57527    False
# 60693    False
# 64307     True
# 66038     True
# 69054     True
# 76118    False
# 77054     True
# 82241    False
# 83328     True
# 83632    False
# Name: languageworkedwith, dtype: bool

# %%
df.loc[filt]['languageworkedwith'].str.contains('JavaScript').sum()
# Out:
# 23

# %%
df['country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: country, Length: 179, dtype: int64

# %%
countryusejava= country_grp['languageworkedwith'].apply(lambda x: x.str.contains('JavaScript').sum())

# %%
countryusejava
# Out:
# country
# Afghanistan                              20
# Albania                                  61
# Algeria                                  83
# Andorra                                   2
# Angola                                    2
#                                        ...
# Venezuela, Bolivarian Republic of...     70
# Viet Nam                                147
# Yemen                                    10
# Zambia                                    9
# Zimbabwe                                 23
# Name: languageworkedwith, Length: 179, dtype: int64

# %%
df_counts = df['country'].value_counts()

# %%
pd_concat = pd.concat([df_counts,countryusejava],axis='columns', sort=False)

# %%
pd_concat.rename(columns={'country':'Country','languageworkedwith':'numof_languageworkedwith'})
# Out:
#                    Country  numof_languageworkedwith
# United States        20949                     14672
# India                 9061                      5697
# Germany               5866                      3577
# United Kingdom        5737                      3946
# Canada                3395                      2323
# ...                    ...                       ...
# Tonga                    1                         0
# Timor-Leste              1                         1
# North Korea              1                         1
# Brunei Darussalam        1                         1
# Chad                     1                         1
#
# [179 rows x 2 columns]
